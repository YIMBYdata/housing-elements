# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## Load sites data, and clean data

# %%
sites_df = gpd.read_file(
    './data/raw_data/housing_sites/xn--Bay_Area_Housing_Opportunity_Sites_Inventory__20072023_-it38a.shp'
)

# %%
sj_sites = sites_df.query('jurisdict == "San Jose" and rhnacyc == "RHNA5"').copy()
sj_sites.fillna(value=np.nan, inplace=True)
sj_sites['allowden'] = sj_sites['allowden'].astype(float)
sj_sites['relcapcty'] = sj_sites['relcapcty'].astype(float)

# %%
is_constant = ((sj_sites == sj_sites.iloc[0]).all())
constant_cols = is_constant[is_constant].index.values
constant_cols
# Out:
# array(['rhnacyc', 'rhnayrs', 'county', 'jurisdict', 'currunits',
#        'allowlow', 'num_vl', 'num_l', 'num_m', 'num_am'], dtype=object)

# %%
sj_sites.drop(constant_cols, axis=1, inplace=True)

# %%
sj_sites.dropna(how='all', axis=1, inplace=True)

# %%
sj_sites.shape
# Out:
# (599, 18)

# %% [markdown]
# ## Load building permits data

# %%
# This data was pulled on 2021-03-08
expired_permits = gpd.read_file('data/raw_data/san_jose/sj_expired_building_permits.shp')
active_permits = gpd.read_file('data/raw_data/san_jose/sj_active_building_permits.shp')

# %%
expired_permits.dropna(how='all', axis='columns', inplace=True)
active_permits.dropna(how='all', axis='columns', inplace=True)

# %%
expired_permits['ISSUEDATE'] = pd.to_datetime(expired_permits['ISSUEDATE'])
expired_permits['ISSUEDATEU'] = pd.to_datetime(expired_permits['ISSUEDATEU'])
expired_permits['LASTUPDATE'] = pd.to_datetime(expired_permits['LASTUPDATE'])

# %%
expired_permits.groupby(pd.Grouper(key='ISSUEDATE', freq='10Y')).size()
# Out:
# ISSUEDATE
# 1938-12-31        1
# 1948-12-31        1
# 1958-12-31        0
# 1968-12-31        1
# 1978-12-31       11
# 1988-12-31       28
# 1998-12-31       47
# 2008-12-31    12541
# 2018-12-31    33210
# 2028-12-31       27
# Freq: 10A-DEC, dtype: int64

# %%
active_permits['ISSUEDATE'] = pd.to_datetime(active_permits['ISSUEDATE'])
active_permits['ISSUEDATEU'] = pd.to_datetime(active_permits['ISSUEDATEU'])
active_permits['LASTUPDATE'] = pd.to_datetime(active_permits['LASTUPDATE'])

# %%
active_permits.groupby(pd.Grouper(key='ISSUEDATE', freq='10Y')).size()
# Out:
# ISSUEDATE
# 1997-12-31        2
# 2007-12-31     1421
# 2017-12-31     2901
# 2027-12-31    17625
# Freq: 10A-DEC, dtype: int64

# %%
expired_permits.iloc[1]
# Out:
# OBJECTID                                              2.0
# APPLICANT                                            NONE
# CONTRACTOR                                           None
# FACILITYID                                              2
# INTID                                                 2.0
# ADDRESS        1490  REDMOND AV  , SAN JOSE CA 95120-4858
# APN                                              57528005
# WORKDESC                            Additions/Alterations
# SUBDESC                                     Single-Family
# PERMITAPPR                                           None
# ISSUEDATE                             1994-03-16 16:00:00
# ISSUEDATEU                            1994-03-17 00:00:00
# FINALDATE                                            None
# FINALDATEU                                           None
# DWELLINGUN                                            0.0
# PERMITVALU                                            0.0
# SQUAREFOOT                                            0.0
# FOLDERNUM                                  1994-033756-RS
# LASTUPDATE                            2020-10-09 02:21:16
# LASTEDITOR                                            FME
# ENTERPRISE                            PLN-PBEX-0000000002
# geometry      POINT (6155198.435434714 1909114.443571478)
# Name: 1, dtype: object

# %%
expired_new_construction = expired_permits[
    expired_permits['WORKDESC'] == 'New Construction'
]

# %%
expired_new_construction['SUBDESC'].value_counts()
# Out:
# Single-Family                   207
# Apt/Condo/Townhouse             184
# 2nd Unit Added                   75
# Retail                           42
# Office                           19
# Townhouse                        14
# Condo                            14
# Mixed Use                        14
# Undefined                        12
# Hotel/Motel                      10
# Duplex                           10
# School/Daycare                   10
# Warehouse/Storage                 7
# Open Public Parking Garage        6
# Restaurant                        6
# Industrial Plant                  5
# Manufactured Home                 5
# Tilt Up Warehouse                 3
# Service Station                   2
# Assembly                          2
# Church                            2
# Recreation Building               2
# Manufacturing                     2
# Medical/Dental Clinic             2
# Multiple Use                      2
# Closed Public Parking Garage      1
# Bank                              1
# High Rise                         1
# Apartment                         1
# Name: SUBDESC, dtype: int64

# %%
expired_new_construction['DWELLINGUN'].value_counts().sort_index()
# Out:
# 0.0      246
# 1.0      261
# 2.0        8
# 3.0        5
# 4.0       14
# 5.0       14
# 6.0       22
# 7.0       30
# 8.0       18
# 9.0       11
# 10.0       4
# 11.0       1
# 12.0       5
# 13.0       1
# 14.0       1
# 17.0       1
# 22.0       5
# 40.0       1
# 45.0       1
# 48.0       1
# 80.0       1
# 86.0       1
# 109.0      1
# 113.0      1
# 117.0      1
# 148.0      1
# 165.0      1
# 205.0      1
# 243.0      1
# 271.0      1
# 330.0      1
# 357.0      1
# 403.0      1
# Name: DWELLINGUN, dtype: int64

# %%
expired_new_construction[
    expired_new_construction['DWELLINGUN'] == 403
]
# Out:
#        OBJECTID                    APPLICANT                   CONTRACTOR  \
# 34475   34507.0  HANOVER RS CONSTRUCTION LLC  HANOVER RS CONSTRUCTION LLC
#
#       FACILITYID    INTID                                    ADDRESS  \
# 34475      34503  34503.0  415 E TAYLOR ST  , SAN JOSE CA 95112-3136
#
#             APN          WORKDESC              SUBDESC  \
# 34475  24909001  New Construction  Apt/Condo/Townhouse
#
#                                               PERMITAPPR  ... FINALDATE  \
# 34475  B-4. Complete, E-4. Complete, P-4. Complete, M...  ...      None
#
#       FINALDATEU DWELLINGUN PERMITVALU  SQUAREFOOT       FOLDERNUM  \
# 34475       None      403.0        0.0    390695.0  2016-132495-MF
#
#                LASTUPDATE LASTEDITOR           ENTERPRISE  \
# 34475 2021-01-09 02:28:09        FME  PLN-PBEX-0000034503
#
#                               geometry
# 34475  POINT (6157176.189 1954347.642)
#
# [1 rows x 22 columns]

# %%
active_new_construction = active_permits[
    active_permits['WORKDESC'] == 'New Construction'
]

# %%
active_new_construction['SUBDESC'].value_counts()
# Out:
# 2nd Unit Added                   541
# Single-Family                    457
# Apt/Condo/Townhouse              225
# Retail                            43
# Office                            38
# Mixed Use                         30
# Hotel/Motel                       19
# Warehouse/Storage                 19
# Condo                             12
# Closed Public Parking Garage       9
# Recreation Building                8
# Apartment                          7
# Restaurant                         5
# Duplex                             5
# Townhouse                          3
# Service Station                    3
# Medical/Dental Clinic              3
# Open Public Parking Garage         3
# School/Daycare                     2
# Assembly                           2
# Undefined                          2
# Industrial Plant                   2
# High Rise                          2
# Data Center                        2
# Health Club                        1
# Address Assignment                 1
# Church                             1
# Convalescent/Residential Care      1
# Commercial/Industrial              1
# Theater                            1
# R & D Lab                          1
# Antenna/Cell Site                  1
# Name: SUBDESC, dtype: int64

# %%
pd.set_option('max_rows', 70)

# %%
active_new_construction['DWELLINGUN'].value_counts().sort_index()
# Out:
# 0.0      222
# 1.0      996
# 2.0        6
# 3.0        6
# 4.0        4
# 5.0       29
# 6.0       30
# 7.0       44
# 8.0       28
# 9.0        2
# 10.0      20
# 11.0       1
# 12.0       1
# 13.0       2
# 16.0       1
# 24.0       2
# 25.0       1
# 31.0       1
# 48.0       1
# 52.0       2
# 55.0       3
# 64.0       1
# 71.0       1
# 77.0       1
# 82.0       1
# 83.0       1
# 84.0       1
# 86.0       1
# 87.0       1
# 92.0       1
# 96.0       1
# 97.0       1
# 102.0      1
# 105.0      1
# 106.0      1
# 112.0      1
# 119.0      1
# 120.0      1
# 130.0      1
# 135.0      2
# 136.0      1
# 162.0      2
# 165.0      1
# 166.0      1
# 176.0      1
# 190.0      2
# 200.0      1
# 219.0      1
# 230.0      1
# 233.0      1
# 249.0      1
# 260.0      1
# 267.0      1
# 268.0      1
# 269.0      1
# 299.0      1
# 301.0      2
# 304.0      1
# 315.0      1
# 318.0      1
# 321.0      1
# 326.0      1
# 357.0      1
# 369.0      1
# 640.0      1
# Name: DWELLINGUN, dtype: int64

# %%
expired_new_construction['APN'].isin(active_new_construction['APN']).mean()
# Out:
# 0.1975867269984917

# %% [markdown]
# Okay, so there is some duplication. We can choose the active one over the expired one.

# %%
combined_df = pd.concat(
    [
        expired_new_construction.assign(state='expired'),
        active_new_construction.assign(state='active'),
    ], 
    ignore_index=True
).drop_duplicates('APN', keep='last')

# %%
combined_df.groupby('APN').size().value_counts()
# Out:
# 1    1050
# dtype: int64

# %%
recent_combined_df = combined_df[
    combined_df['ISSUEDATE'] >= '2015-01-01'
]

# %%
recent_combined_df.shape
# Out:
# (819, 23)

# %% [markdown]
# # Merge DataFrames

# %%
merged_df = sj_sites.merge(
    recent_combined_df,
    left_on='locapn',
    right_on='APN',
    how='left'
)

# %%
merged_df
# Out:
#      objectid         apn    locapn genplan zoning    gacres  locacres  \
# 0       66203  249-41-024  24941024      RN    R-M  0.150000      0.14
# 1       66555  249-41-022  24941022      RN    R-M  0.168000      0.14
# 2       76446  274-16-029  27416029      UV     CP  0.118000      0.86
# 3       77834  274-59-001  27459001      UV     CO  0.614000      1.98
# 4       77839  277-18-023  27718023      UV     CN  0.221000      0.74
# ..        ...         ...       ...     ...    ...       ...       ...
# 594     84228    48109049  48109049      UV   MS-G  1.036080      1.78
# 595     84240    27441115  27441115      UV     CP  0.165030      0.16
# 596     84250    61270016  61270016      LH      A  7.122983     11.71
# 597     84251    66003013  66003013      RR  A(PD)  2.075477      2.35
# 598     84252    27715056  27715056      UV      A  0.287774      0.29
#
#      allowden  allowhigh  relcapcty  ... FINALDATEU DWELLINGUN PERMITVALU  \
# 0         8.0          8        1.0  ...        NaN        NaN        NaN
# 1         8.0          8        1.0  ...        NaN        NaN        NaN
# 2        12.4         12       11.0  ...        NaN        NaN        NaN
# 3        12.4         12       25.0  ...        NaN        NaN        NaN
# 4        12.4         12        9.0  ...        NaN        NaN        NaN
# ..        ...        ...        ...  ...        ...        ...        ...
# 594      12.1         12       22.0  ...        NaN        NaN        NaN
# 595      12.4         12        2.0  ...        NaN        NaN        NaN
# 596       0.2          0        2.0  ...        NaN        NaN        NaN
# 597       1.9          2        3.0  ...        NaN        NaN        NaN
# 598      12.4         12        4.0  ...        NaN        NaN        NaN
#
#     SQUAREFOOT FOLDERNUM  LASTUPDATE  LASTEDITOR ENTERPRISE  geometry_y state
# 0          NaN       NaN         NaT         NaN        NaN        None   NaN
# 1          NaN       NaN         NaT         NaN        NaN        None   NaN
# 2          NaN       NaN         NaT         NaN        NaN        None   NaN
# 3          NaN       NaN         NaT         NaN        NaN        None   NaN
# 4          NaN       NaN         NaT         NaN        NaN        None   NaN
# ..         ...       ...         ...         ...        ...         ...   ...
# 594        NaN       NaN         NaT         NaN        NaN        None   NaN
# 595        NaN       NaN         NaT         NaN        NaN        None   NaN
# 596        NaN       NaN         NaT         NaN        NaN        None   NaN
# 597        NaN       NaN         NaT         NaN        NaN        None   NaN
# 598        NaN       NaN         NaT         NaN        NaN        None   NaN
#
# [599 rows x 41 columns]

# %%
merged_df['state'].notnull().mean()
# Out:
# 0.05175292153589316

# %%
merged_df.columns
# Out:
# Index(['objectid', 'apn', 'locapn', 'genplan', 'zoning', 'gacres', 'locacres',
#        'allowden', 'allowhigh', 'relcapcty', 'desafford', 'sitetype',
#        'pdaparcel', 'existuse', 'localnote', 'Shape__Are', 'Shape__Len',
#        'geometry_x', 'OBJECTID', 'APPLICANT', 'CONTRACTOR', 'FACILITYID',
#        'INTID', 'ADDRESS', 'APN', 'WORKDESC', 'SUBDESC', 'PERMITAPPR',
#        'ISSUEDATE', 'ISSUEDATEU', 'FINALDATE', 'FINALDATEU', 'DWELLINGUN',
#        'PERMITVALU', 'SQUAREFOOT', 'FOLDERNUM', 'LASTUPDATE', 'LASTEDITOR',
#        'ENTERPRISE', 'geometry_y', 'state'],
#       dtype='object')

# %%
merged_df[
    merged_df['state'].notnull()
][['ADDRESS', 'allowden', 'allowhigh', 'relcapcty', 'DWELLINGUN', 'zoning']]
# Out:
#                                                ADDRESS  allowden  allowhigh  \
# 20        1690  SOUTHWEST EX  , SAN JOSE CA 95126-0000      66.0         66
# 21                      7020  LIVERY LN  , SAN JOSE CA       1.2          1
# 23         1787  LUCRETIA AV  , SAN JOSE CA 95122-3814      14.4         14
# 192  1364  TIFFANY CANYON CT  , SAN JOSE CA 95120-0000       0.2          0
# 222                 734 N 12TH ST  , SAN JOSE CA 95112       8.0          8
# 267          201  BASSETT ST  , SAN JOSE CA 95128-0000     184.9        185
# 268             252 N 1ST ST  , SAN JOSE CA 95113-1002     140.3        140
# 280         6462  ALMADEN RD  , SAN JOSE CA 95120-1901       8.0          8
# 306    5048  BROOK VALLEY LP  , SAN JOSE CA 95123-0000       8.0          8
# 346        16607  ALMADEN EX  , SAN JOSE CA 95120-0000      50.0         50
# 362          138  BALBACH ST  , SAN JOSE CA 95110-2807      64.3         64
# 370               28 N ALMADEN AV  , SAN JOSE CA 95113     175.0        175
# 386           345  DELMAS AV  , SAN JOSE CA 95126-3626     175.0        175
# 394     386 W SANTA CLARA ST  , SAN JOSE CA 95113-1503     145.0        145
# 399   4714  TINA SPECIALE DR  , SAN JOSE CA 95136-2757      11.2         11
# 402          1097  JAYDEN LN  , SAN JOSE CA 95120-1506       6.9          7
# 411          423  DOUGLAS PL  , SAN JOSE CA 95126-3221      14.0         14
# 413             975 S 1ST ST  , SAN JOSE CA 95110-3128      46.8         47
# 415            476  AGORA CT  , SAN JOSE CA 95123-3142      15.7         16
# 425        2842  MOORPARK AV  , SAN JOSE CA 95128-3156       4.9          5
# 427          370  NEILSON CT  , SAN JOSE CA 95111-3813       2.3          2
# 438          2450  SENTER RD  , SAN JOSE CA 95111-1040      29.5         30
# 449   2317  STEVENS CREEK BL  , SAN JOSE CA 95128-1609      12.4         12
# 473            222  FLOYD ST  , SAN JOSE CA 95110-3344      11.8         12
# 476           646  WILLOW ST  , SAN JOSE CA 95125-5714       8.2          8
# 486          415 E TAYLOR ST  , SAN JOSE CA 95112-3136      35.4         35
# 495                 1144 S 2ND ST  , SAN JOSE CA 95112     116.4        116
# 510        255 E VIRGINIA ST  , SAN JOSE CA 95112-3529     100.0        100
# 513     298  LAUREL GROVE LN  , SAN JOSE CA 95126-4831      95.3         95
# 586              178  VELOCITY WY  , SAN JOSE CA 95110      46.6         47
# 590      808 W SAN CARLOS ST  , SAN JOSE CA 95126-3526      67.3         67
#
#      relcapcty  DWELLINGUN zoning
# 20        64.0         0.0  A(PD)
# 21         7.0         1.0  A(PD)
# 23        20.0         1.0  A(PD)
# 192        2.0         1.0  A(PD)
# 222        1.0         1.0    R-2
# 267      135.0         0.0     DC
# 268      216.0         0.0     DC
# 280        7.0         1.0  R-1-8
# 306       20.0         1.0     LI
# 346       40.0         0.0     CP
# 362      101.0         0.0  A(PD)
# 370      117.0         0.0     DC
# 386      144.0         0.0     LI
# 394      325.0         0.0  A(PD)
# 399       13.0         1.0  A(PD)
# 402        6.0         1.0  A(PD)
# 411        6.0         1.0  A(PD)
# 413       50.0         0.0  A(PD)
# 415        8.0         1.0  A(PD)
# 425        2.0         1.0  A(PD)
# 427        3.0         1.0  A(PD)
# 438      102.0         0.0  A(PD)
# 449       13.0         0.0     CP
# 473        3.0         1.0  A(PD)
# 476        3.0         1.0  A(PD)
# 486      403.0       403.0  A(PD)
# 495      134.0         0.0  A(PD)
# 510      123.0       301.0  A(PD)
# 513      181.0         0.0  A(PD)
# 586       14.0         7.0     DC
# 590      315.0         0.0     HI

# %% [markdown]
# Okay, looks like the data isn't super complete, so we can't really determine how the planned densities compare to the actually built densities.
# We can still look at development probabilities though.

# %%
merged_df.dropna(subset=['state'])['zoning'].value_counts()
# Out:
# A(PD)    20
# DC        4
# CP        2
# LI        2
# R-1-8     1
# R-2       1
# HI        1
# Name: zoning, dtype: int64

# %% [markdown]
# * A(PD) means Agricultural, but with a Planned Development overlay
# * DC means Downtown Primary Commercial District
# * CP means Commercial Pedestrian
# * LI means Light Industrial
# * R-1-8 means residential, 8 dwelling units/acre
# * R-2 is residential, higher density than R-1
# * HI means Heavy Industrial

# %%
merged_df['zoning'].value_counts()
# Out:
# A(PD)        160
# CP            61
# R-1-8         60
# County        43
# DC            36
# LI            34
# R-2           26
# CG            26
# R-M           25
# R-1-5         24
# A             22
# MS-G          16
# CN            14
# HI            14
# CO            10
# R-1-2          6
# IP             3
# R-1-1          3
# R-1-5(PD)      3
# R-1-2(PD)      2
# CP(PD)         1
# CG/R-M         1
# R-1-8(PD)      1
# R-M(PD)        1
# R-1-RR         1
# DC-NT1         1
# CN(PD)         1
# CG(PD)         1
# R-2/LI         1
# OS             1
# MS-C           1
# Name: zoning, dtype: int64

# %%
merged_df.groupby('zoning').apply(lambda g: g['state'].notnull().mean())
# Out:
# zoning
# A            0.000000
# A(PD)        0.125000
# CG           0.000000
# CG(PD)       0.000000
# CG/R-M       0.000000
# CN           0.000000
# CN(PD)       0.000000
# CO           0.000000
# CP           0.032787
# CP(PD)       0.000000
# County       0.000000
# DC           0.111111
# DC-NT1       0.000000
# HI           0.071429
# IP           0.000000
# LI           0.058824
# MS-C         0.000000
# MS-G         0.000000
# OS           0.000000
# R-1-1        0.000000
# R-1-2        0.000000
# R-1-2(PD)    0.000000
# R-1-5        0.000000
# R-1-5(PD)    0.000000
# R-1-8        0.016667
# R-1-8(PD)    0.000000
# R-1-RR       0.000000
# R-2          0.038462
# R-2/LI       0.000000
# R-M          0.000000
# R-M(PD)      0.000000
# dtype: float64
