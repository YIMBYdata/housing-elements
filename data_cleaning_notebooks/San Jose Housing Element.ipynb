# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## Load sites data, and clean data

# %%
sites_df = gpd.read_file(
    './data/raw_data/housing_sites/xn--Bay_Area_Housing_Opportunity_Sites_Inventory__20072023_-it38a.shp'
)

# %%
sj_sites = sites_df.query('jurisdict == "San Jose" and rhnacyc == "RHNA5"').copy()
sj_sites.fillna(value=np.nan, inplace=True)
sj_sites['allowden'] = sj_sites['allowden'].astype(float)
sj_sites['relcapcty'] = sj_sites['relcapcty'].astype(float)

# %%
is_constant = ((sj_sites == sj_sites.iloc[0]).all())
constant_cols = is_constant[is_constant].index.values
constant_cols
# Out:
# array(['rhnacyc', 'rhnayrs', 'county', 'jurisdict', 'currunits',
#        'allowlow', 'num_vl', 'num_l', 'num_m', 'num_am'], dtype=object)

# %%
sj_sites.drop(constant_cols, axis=1, inplace=True)

# %%
sj_sites.dropna(how='all', axis=1, inplace=True)

# %%
sj_sites.shape
# Out:
# (599, 18)

# %% [markdown]
# ## Load building permits data

# %%
# This data was pulled on 2021-03-08
expired_permits = gpd.read_file('data/raw_data/san_jose/sj_expired_building_permits.shp')
active_permits = gpd.read_file('data/raw_data/san_jose/sj_active_building_permits.shp')

# %%
expired_permits.dropna(how='all', axis='columns', inplace=True)
active_permits.dropna(how='all', axis='columns', inplace=True)

# %%
expired_permits['ISSUEDATE'] = pd.to_datetime(expired_permits['ISSUEDATE'])
expired_permits['ISSUEDATEU'] = pd.to_datetime(expired_permits['ISSUEDATEU'])
expired_permits['LASTUPDATE'] = pd.to_datetime(expired_permits['LASTUPDATE'])

# %%
expired_permits.groupby(pd.Grouper(key='ISSUEDATE', freq='10Y')).size()
# Out:
# ISSUEDATE
# 1938-12-31        1
# 1948-12-31        1
# 1958-12-31        0
# 1968-12-31        1
# 1978-12-31       11
# 1988-12-31       28
# 1998-12-31       47
# 2008-12-31    12541
# 2018-12-31    33210
# 2028-12-31       27
# Freq: 10A-DEC, dtype: int64

# %%
active_permits['ISSUEDATE'] = pd.to_datetime(active_permits['ISSUEDATE'])
active_permits['ISSUEDATEU'] = pd.to_datetime(active_permits['ISSUEDATEU'])
active_permits['LASTUPDATE'] = pd.to_datetime(active_permits['LASTUPDATE'])

# %%
active_permits.groupby(pd.Grouper(key='ISSUEDATE', freq='10Y')).size()
# Out:
# ISSUEDATE
# 1997-12-31        2
# 2007-12-31     1421
# 2017-12-31     2901
# 2027-12-31    17625
# Freq: 10A-DEC, dtype: int64

# %%
expired_permits.iloc[1]
# Out:
# OBJECTID                                              2.0
# APPLICANT                                            NONE
# CONTRACTOR                                           None
# FACILITYID                                              2
# INTID                                                 2.0
# ADDRESS        1490  REDMOND AV  , SAN JOSE CA 95120-4858
# APN                                              57528005
# WORKDESC                            Additions/Alterations
# SUBDESC                                     Single-Family
# PERMITAPPR                                           None
# ISSUEDATE                             1994-03-16 16:00:00
# ISSUEDATEU                            1994-03-17 00:00:00
# FINALDATE                                            None
# FINALDATEU                                           None
# DWELLINGUN                                            0.0
# PERMITVALU                                            0.0
# SQUAREFOOT                                            0.0
# FOLDERNUM                                  1994-033756-RS
# LASTUPDATE                            2020-10-09 02:21:16
# LASTEDITOR                                            FME
# ENTERPRISE                            PLN-PBEX-0000000002
# geometry      POINT (6155198.435434714 1909114.443571478)
# Name: 1, dtype: object

# %%
expired_new_construction = expired_permits[
    expired_permits['WORKDESC'] == 'New Construction'
]

# %%
expired_new_construction['SUBDESC'].value_counts()
# Out:
# Single-Family                   207
# Apt/Condo/Townhouse             184
# 2nd Unit Added                   75
# Retail                           42
# Office                           19
# Mixed Use                        14
# Townhouse                        14
# Condo                            14
# Undefined                        12
# Duplex                           10
# Hotel/Motel                      10
# School/Daycare                   10
# Warehouse/Storage                 7
# Open Public Parking Garage        6
# Restaurant                        6
# Manufactured Home                 5
# Industrial Plant                  5
# Tilt Up Warehouse                 3
# Recreation Building               2
# Assembly                          2
# Medical/Dental Clinic             2
# Church                            2
# Service Station                   2
# Multiple Use                      2
# Manufacturing                     2
# Closed Public Parking Garage      1
# Apartment                         1
# Bank                              1
# High Rise                         1
# Name: SUBDESC, dtype: int64

# %%
expired_new_construction['DWELLINGUN'].value_counts().sort_index()
# Out:
# 0.0      246
# 1.0      261
# 2.0        8
# 3.0        5
# 4.0       14
# 5.0       14
# 6.0       22
# 7.0       30
# 8.0       18
# 9.0       11
# 10.0       4
# 11.0       1
# 12.0       5
# 13.0       1
# 14.0       1
# 17.0       1
# 22.0       5
# 40.0       1
# 45.0       1
# 48.0       1
# 80.0       1
# 86.0       1
# 109.0      1
# 113.0      1
# 117.0      1
# 148.0      1
# 165.0      1
# 205.0      1
# 243.0      1
# 271.0      1
# 330.0      1
# 357.0      1
# 403.0      1
# Name: DWELLINGUN, dtype: int64

# %%
expired_new_construction[
    expired_new_construction['DWELLINGUN'] == 403
]
# Out:
#        OBJECTID                    APPLICANT                   CONTRACTOR  \
# 34475   34507.0  HANOVER RS CONSTRUCTION LLC  HANOVER RS CONSTRUCTION LLC
#
#       FACILITYID    INTID                                    ADDRESS  \
# 34475      34503  34503.0  415 E TAYLOR ST  , SAN JOSE CA 95112-3136
#
#             APN          WORKDESC              SUBDESC  \
# 34475  24909001  New Construction  Apt/Condo/Townhouse
#
#                                               PERMITAPPR  ... FINALDATE  \
# 34475  B-4. Complete, E-4. Complete, P-4. Complete, M...  ...      None
#
#       FINALDATEU DWELLINGUN PERMITVALU  SQUAREFOOT       FOLDERNUM  \
# 34475       None      403.0        0.0    390695.0  2016-132495-MF
#
#                LASTUPDATE LASTEDITOR           ENTERPRISE  \
# 34475 2021-01-09 02:28:09        FME  PLN-PBEX-0000034503
#
#                               geometry
# 34475  POINT (6157176.189 1954347.642)
#
# [1 rows x 22 columns]

# %%
active_new_construction = active_permits[
    active_permits['WORKDESC'] == 'New Construction'
]

# %%
active_new_construction['SUBDESC'].value_counts()
# Out:
# 2nd Unit Added                   541
# Single-Family                    457
# Apt/Condo/Townhouse              225
# Retail                            43
# Office                            38
# Mixed Use                         30
# Warehouse/Storage                 19
# Hotel/Motel                       19
# Condo                             12
# Closed Public Parking Garage       9
# Recreation Building                8
# Apartment                          7
# Restaurant                         5
# Duplex                             5
# Townhouse                          3
# Service Station                    3
# Open Public Parking Garage         3
# Medical/Dental Clinic              3
# Data Center                        2
# Undefined                          2
# High Rise                          2
# School/Daycare                     2
# Assembly                           2
# Industrial Plant                   2
# Address Assignment                 1
# Health Club                        1
# Commercial/Industrial              1
# Convalescent/Residential Care      1
# Theater                            1
# Church                             1
# Antenna/Cell Site                  1
# R & D Lab                          1
# Name: SUBDESC, dtype: int64

# %%
pd.set_option('max_rows', 70)

# %%
expired_new_construction['APN'].isin(active_new_construction['APN']).mean()
# Out:
# 0.1975867269984917

# %% [markdown]
# Okay, so there is some duplication. We can choose the active one over the expired one.

# %%
combined_df = pd.concat(
    [
        expired_new_construction.assign(state='expired'),
        active_new_construction.assign(state='active'),
    ], 
    ignore_index=True
).drop_duplicates('APN', keep='last')

# %%
combined_df['SUBDESC'].value_counts()
# Out:
# 2nd Unit Added                   607
# Single-Family                    131
# Apt/Condo/Townhouse               79
# Retail                            47
# Office                            28
# Mixed Use                         27
# Warehouse/Storage                 18
# Hotel/Motel                       15
# Duplex                             9
# Condo                              9
# Townhouse                          7
# School/Daycare                     7
# Recreation Building                6
# Closed Public Parking Garage       6
# Industrial Plant                   6
# Apartment                          6
# Medical/Dental Clinic              5
# Restaurant                         5
# Undefined                          5
# Service Station                    4
# Open Public Parking Garage         4
# Assembly                           3
# Data Center                        2
# Manufactured Home                  2
# Church                             2
# Commercial/Industrial              1
# Antenna/Cell Site                  1
# Address Assignment                 1
# High Rise                          1
# Multiple Use                       1
# Tilt Up Warehouse                  1
# R & D Lab                          1
# Manufacturing                      1
# Convalescent/Residential Care      1
# Name: SUBDESC, dtype: int64

# %%
combined_df[
    combined_df['DWELLINGUN'] > 0
]['SUBDESC'].value_counts()
# Out:
# 2nd Unit Added                  607
# Single-Family                   119
# Apt/Condo/Townhouse              56
# Duplex                            8
# Townhouse                         6
# Condo                             6
# Apartment                         5
# Manufactured Home                 2
# Hotel/Motel                       2
# Industrial Plant                  1
# Office                            1
# Retail                            1
# Closed Public Parking Garage      1
# Tilt Up Warehouse                 1
# Name: SUBDESC, dtype: int64

# %%
recent_new_construction_df = combined_df[
    (combined_df['WORKDESC'] == 'New Construction')
    & (combined_df['DWELLINGUN'] > 0)
    & (combined_df['ISSUEDATE'] >= '2015-01-01')
    & ~recent_new_construction_df['SUBDESC'].isin(['2nd Unit Added', 'Single-Family'])  # let's ignore ADUs and SFH rebuilds for now
]

# %%
recent_new_construction_df
# Out:
#       OBJECTID                                          APPLICANT  \
# 459    25993.0                                 KB HOME SO BAY INC
# 477    27423.0                DIABLO VENTURES INC  JOSIAH DENMARK
# 507    30442.0                                    TNHC HW S J LLC
# 524    32982.0                                         LIN CONNIE
# 539    34507.0                        HANOVER RS CONSTRUCTION LLC
# Out:
# 1416.0

# %%
recent_new_construction_df[
    recent_new_construction_df['APN'].isin(sj_sites['locapn'])
]['DWELLINGUN'].sum()
# Out:
# 712.0

# %%
712 / 1416
# Out:
# 0.5028248587570622

# %%
combined_df[
    (combined_df['DWELLINGUN'] == 0)
    & (combined_df['ISSUEDATE'] >= '2015-01-01'
]['APN'].isin(sj_sites['locapn']).mean()
# Out:
# 0.1

# %%
combined_df[
    (combined_df['DWELLINGUN'] == 0)
    & (combined_df['ISSUEDATE'] >= '2015-01-01')
]
# Out:
#       OBJECTID                                   APPLICANT  \
# 461    26017.0                 TYPOGRAFIKS INC  ELIE HABIB
# 464    26309.0                    SAVIDGE CONSTRUCTION INC
# 495    28911.0                     LUSARDI CONSTRUCTION CO
# 509    30576.0             VER CONSULTANTS  VINCENT RIVERO
# 516    31890.0  M.A.K. ASSOCIATES, INC  RICHARD MACDERMOTT
# ...        ...                                         ...
# 1968   27270.0            B & T SERVICE STATION CONTRACTOR
# 1986   27581.0                             DANIELLE WILSON
# 2021   28839.0    DURAIRAJ SUNDAR AND SUNDAR JASMINE N TRU
# 2076   30538.0               REPUBLIC URBAN PROPERTIES LLC
# 2094   31161.0                KAISER FDN HLTH PLN/TX & INS
#
#                             CONTRACTOR FACILITYID    INTID  \
# 461                               None      25999  25999.0
# 464           SAVIDGE CONSTRUCTION INC      26293  26293.0
# 495            LUSARDI CONSTRUCTION CO      28898  28898.0
# 509       SAN JOSE CONSTRUCTION CO INC      30563  30563.0
# 516             M.A.K. ASSOCIATES, INC      31881  31881.0
# ...                                ...        ...      ...
# 1968  B & T SERVICE STATION CONTRACTOR      21086  21086.0
# 1986                              None      21424  21424.0
# 2021                              None       4231   4231.0
# 2076                              None       2509   2509.0
# 2094      KAISER FDN HLTH PLN/TX & INS      21451  21451.0
#
#                                                ADDRESS       APN  \
# 461   2317  STEVENS CREEK BL  , SAN JOSE CA 95128-1609  27457008
# 464          5422  CAMDEN AV  , SAN JOSE CA 95124-5825  56916016
# 495             6280  AMERICA CENTER DR  , SAN JOSE CA  01545037
# 509    708  RIDDER PARK DR 22 , SAN JOSE CA 95131-0000  23705016
# 516            585 W ALMA AV  , SAN JOSE CA 95125-1743  43414075
# ...                                                ...       ...
# 1968           1433  BERRYESSA RD  , SAN JOSE CA 95133  24104022
# 1986       6402  SANTA TERESA BL 4 , SAN JOSE CA 95119  70603016
# 2021     1114  HUNTINGDON DR  , SAN JOSE CA 95129-3123  37811014
# 2076        1096  LINCOLN AV  , SAN JOSE CA 95125-3110  26456082
# 2094        283  INTERNATIONAL CL  , SAN JOSE CA 95119  70605018
#
#               WORKDESC             SUBDESC  \
# 461   New Construction           Mixed Use
# 464   New Construction     Service Station
# 495   New Construction              Office
# 509   New Construction           Mixed Use
# 516   New Construction      School/Daycare
# ...                ...                 ...
# 1968  New Construction     Service Station
# 1986  New Construction   Warehouse/Storage
# 2021  New Construction  Address Assignment
# 2076  New Construction           Mixed Use
# 2094  New Construction              Office
#
#                                              PERMITAPPR  ... FINALDATEU  \
# 461   B-4. Complete, E-4. Complete, P-4. Complete, M...  ...       None
# 464   B-4. Complete, E-4. Complete, P-4. Complete, M...  ...       None
# 495         B-2. Fnd only, E-2. Fnd only, P-2. Fnd only  ...       None
# 509         B-2. Fnd only, E-4. Complete, P-4. Complete  ...       None
# 516   B-4. Complete, E-4. Complete, P-4. Complete, M...  ...       None
# ...                                                 ...  ...        ...
# 1968  B-4. Complete, E-4. Complete, P-4. Complete, M...  ...       None
# 1986                                      B-4. Complete  ...       None
# 2021                                               None  ...       None
# 2076  B-2. Fnd only, E-2. Fnd only, P-2. Fnd only, M...  ...       None
# 2094                                      B-4. Complete  ...       None
#
#      DWELLINGUN PERMITVALU SQUAREFOOT       FOLDERNUM          LASTUPDATE  \
# 461         0.0        0.0     3884.0  2015-013690-CI 2021-01-09 02:27:03
# 464         0.0        0.0     6662.0  2014-045061-CI 2021-01-09 02:27:07
# 495         0.0        0.0        0.0  2015-037613-CI 2021-01-09 02:27:25
# 509         0.0        0.0   162500.0  2016-118310-CI 2021-01-09 02:27:39
# 516         0.0        0.0     5100.0  2016-100195-CI 2021-01-09 02:27:48
# ...         ...        ...        ...             ...                 ...
# 1968        0.0        0.0     8920.0  2020-148965-CI 2021-01-09 02:23:15
# 1986        0.0        0.0      991.0  2020-149161-CI 2021-01-09 02:23:17
# 2021        0.0        0.0        0.0  2021-011589-IR 2021-01-15 02:20:47
# 2076        0.0        0.0        0.0  2021-015100-CI 2021-03-05 02:20:36
# 2094        0.0        0.0     2424.0  2021-014498-CI 2021-02-24 02:22:00
#
#       LASTEDITOR           ENTERPRISE                         geometry  \
# 461          FME  PLN-PBEX-0000025999  POINT (6144396.316 1943438.743)
# 464          FME  PLN-PBEX-0000026293  POINT (6153094.228 1913140.937)
# 495          FME  PLN-PBEX-0000028898  POINT (6132283.829 1978526.065)
# 509          FME  PLN-PBEX-0000030563  POINT (6154540.656 1962144.342)
# 516          FME  PLN-PBEX-0000031881  POINT (6158130.170 1938051.886)
# ...          ...                  ...                              ...
# 1968         FME  PLN-PBAC-0000021086  POINT (6160614.082 1959720.896)
# 1986         FME  PLN-PBAC-0000021424  POINT (6185553.311 1911667.306)
# 2021         FME  PLN-PBAC-0000004231  POINT (6124665.085 1937077.492)
# 2076         FME  PLN-PBAC-0000002509  POINT (6154244.413 1937988.522)
# 2094         FME  PLN-PBAC-0000021451  POINT (6183324.080 1912088.167)
#
#         state
# 461   expired
# 464   expired
# 495   expired
# 509   expired
# 516   expired
# ...       ...
# 1968   active
# 1986   active
# 2021   active
# 2076   active
# 2094   active
#
# [140 rows x 23 columns]

# %%
combined_df.groupby('APN').size().value_counts()
# Out:
# 1    1050
# dtype: int64

# %%
recent_combined_df = combined_df[
    (combined_df['ISSUEDATE'] >= '2015-01-01')
    & (combined_df['ISSUEDATE'] < '2021-01-01')
]

# %%
recent_combined_df.shape
# Out:
# (726, 23)

# %%
recent_combined_df_through_2019 = combined_df[
    (combined_df['ISSUEDATE'] >= '2015-01-01')
    & (combined_df['ISSUEDATE'] < '2020-01-01')
]

# %%
recent_combined_df_through_2019.shape
# Out:
# (398, 23)

# %%
recent_combined_df[
    recent_combined_df['ISSUEDATE'] >= '2020-01-01'
]['APN'].isin(sj_sites['locapn']).mean()
# Out:
# 0.003048780487804878

# %%
recent_combined_df['APN'].isin(sj_sites['locapn']).mean()
# Out:
# 0.04269972451790634

# %% [markdown]
# # Merge DataFrames

# %%
recent_combined_df['APN'].value_counts().value_counts()
# Out:
# 1    819
# Name: APN, dtype: int64

# %%
sj_sites['locapn'].value_counts().value_counts()
# Out:
# 1    581
# 2      6
# 3      2
# Name: locapn, dtype: int64

# %%
sj_sites_deduped = sj_sites.sort_values('relcapcty').drop_duplicates('locapn', keep='last')

# %%
sj_sites_deduped['locapn'].value_counts().value_counts()
# Out:
# 1    589
# Name: locapn, dtype: int64

# %%
merged_df = sj_sites_deduped.merge(
    recent_combined_df,
    left_on='locapn',
    right_on='APN',
    how='left'
)

# %%
merged_df['state'].notnull().mean()
# Out:
# 0.05263157894736842

# %%
8/6 * merged_df['state'].notnull().mean()
# Out:
# 0.07017543859649122

# %%
merged_df[
    merged_df['state'].notnull()
][['ADDRESS', 'allowden', 'allowhigh', 'relcapcty', 'DWELLINGUN', 'zoning']].head(12)
# Out:
#                                                ADDRESS  allowden  allowhigh  \
# 24                  734 N 12TH ST  , SAN JOSE CA 95112       8.0          8
# 64         2842  MOORPARK AV  , SAN JOSE CA 95128-3156       4.9          5
# 108  1364  TIFFANY CANYON CT  , SAN JOSE CA 95120-0000       0.2          0
# 135          370  NEILSON CT  , SAN JOSE CA 95111-3813       2.3          2
# 146            222  FLOYD ST  , SAN JOSE CA 95110-3344      11.8         12
# 147           646  WILLOW ST  , SAN JOSE CA 95125-5714       8.2          8
# 253          423  DOUGLAS PL  , SAN JOSE CA 95126-3221      14.0         14
# 254          1097  JAYDEN LN  , SAN JOSE CA 95120-1506       6.9          7
# 259         6462  ALMADEN RD  , SAN JOSE CA 95120-1901       8.0          8
# 278                     7020  LIVERY LN  , SAN JOSE CA       1.2          1
# 283            476  AGORA CT  , SAN JOSE CA 95123-3142      15.7         16
# 349   2317  STEVENS CREEK BL  , SAN JOSE CA 95128-1609      12.4         12
#
#      relcapcty  DWELLINGUN zoning
# 24         1.0         1.0    R-2
# 64         2.0         1.0  A(PD)
# 108        2.0         1.0  A(PD)
# 135        3.0         1.0  A(PD)
# 146        3.0         1.0  A(PD)
# 147        3.0         1.0  A(PD)
# 253        6.0         1.0  A(PD)
# 254        6.0         1.0  A(PD)
# 259        7.0         1.0  R-1-8
# 278        7.0         1.0  A(PD)
# 283        8.0         1.0  A(PD)
# 349       13.0         0.0     CP

# %% [markdown]
# Okay, looks like the data isn't super complete, so we can't really determine how the planned densities compare to the actually built densities.
# We can still look at development probabilities though.

# %%
merged_df['locapn'].value_counts().value_counts()
# Out:
# 1    589
# Name: locapn, dtype: int64

# %%
merged_df.dropna(subset=['state'])['zoning'].value_counts()
# Out:
# A(PD)    20
# DC        4
# LI        2
# CP        2
# R-2       1
# HI        1
# R-1-8     1
# Name: zoning, dtype: int64

# %% [markdown]
# * A(PD) means Agricultural, but with a Planned Development overlay
# * DC means Downtown Primary Commercial District
# * CP means Commercial Pedestrian
# * LI means Light Industrial
# * R-1-8 means residential, 8 dwelling units/acre
# * R-2 is residential, higher density than R-1
# * HI means Heavy Industrial

# %%
zone_mappings = {
    'A(PD)': 'Agricultural',
    'R-1': 'Residential',
    'R-2': 'Residential',
    'R-M': 'Residential',
    'DC': 'Commercial',
    'CG': 'Commercial',
    'CP': 'Commercial',
    'CN': 'Commercial',
    'MS': 'Commercial',
    'CO': 'Commercial',
    'OS': 'Open Space',
    'LI': 'Industrial',
    'IP': 'Industrial',
    'HI': 'Industrial',
    'A': 'Agricultural',
    'County': 'County/Other',
}

# %%
def get_zone_mapping(zone):
    for zone_match_string, zone_type in zone_mappings.items():
        if zone_match_string in zone:
            return zone_type
    return None

merged_df_with_types = merged_df.copy()
merged_df_with_types['zoning_type'] = merged_df_with_types['zoning'].map(get_zone_mapping)

# %%
merged_df_with_types[
    merged_df_with_types['zoning_type'].isnull()
]['zoning'].value_counts()
# Out:
# Series([], Name: zoning, dtype: int64)

# %% [markdown]
# Nice, so we labeled all of them.

# %%
merged_df_with_types.groupby('zoning_type').apply(lambda g: g['state'].notnull().mean())
# Out:
# zoning_type
# Agricultural    0.114943
# Commercial      0.035714
# County/Other    0.000000
# Industrial      0.058824
# Open Space      0.000000
# Residential     0.013158
# dtype: float64

# %%
8/6 * merged_df_with_types.groupby('zoning_type').apply(lambda g: g['state'].notnull().mean())
# Out:
# zoning_type
# Agricultural    0.153257
# Commercial      0.047619
# County/Other    0.000000
# Industrial      0.078431
# Open Space      0.000000
# Residential     0.017544
# dtype: float64

# %% [markdown]
# ## Same analysis, through 2019

# %%
merged_df_through_2019 = sj_sites_deduped.merge(
    recent_combined_df_through_2019,
    left_on='locapn',
    right_on='APN',
    how='left'
)

# %%
merged_df_through_2019['state'].notnull().mean()
# Out:
# 0.050933786078098474

# %%
8/5 * merged_df_through_2019['state'].notnull().mean()
# Out:
# 0.08149405772495756

# %%
merged_df_through_2019_with_types = merged_df_through_2019.copy()
merged_df_through_2019_with_types['zoning_type'] = merged_df_through_2019_with_types['zoning'].map(get_zone_mapping)

# %%
merged_df_through_2019_with_types.groupby('zoning_type').apply(lambda g: g['state'].notnull().mean())
# Out:
# zoning_type
# Agricultural    0.109195
# Commercial      0.035714
# County/Other    0.000000
# Industrial      0.058824
# Open Space      0.000000
# Residential     0.013158
# dtype: float64

# %%
8/5 * merged_df_through_2019_with_types.groupby('zoning_type').apply(lambda g: g['state'].notnull().mean())
# Out:
# zoning_type
# Agricultural    0.174713
# Commercial      0.057143
# County/Other    0.000000
# Industrial      0.094118
# Open Space      0.000000
# Residential     0.021053
# dtype: float64
